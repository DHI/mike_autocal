# %% [markdown]
# ## Example Points Observation Data
# The simulation time of the .m21fm file in this example has been intentionally kept short. This adjustment allows for faster calculations within the notebook, making it easier to demonstrate the general usage of the package.
#
# Please note that due to the shortened simulation period, the quality of the results is not representative of a full-scale analysis. This example is intended solely for demonstration purposes and should not be used for detailed assessments or decision-making.

# %% [markdown]
# ##### Import

# %%
from pathlib import Path
from datetime import datetime

import optuna
from mike_autocal.autocal import AutoCal
from mike_autocal.dataio import ObservationData, SimObsPair, SimulationData
from mike_autocal.measurement_fun import ManningFile
from mike_autocal.mikesimulation import Launcher, RunTimeEvaluation
from mike_autocal.objective_fun import AMEANOuterMetric, RMSEInnerMetric

ROOT_DIR = Path().resolve()

# %% [markdown]
# ##### Basic autocal input
#
# - `study_name` - Unique identifier for this calibration study using satellite altimetry data.
# - `simfile` - Base MIKE model file to be calibrated.
# - `evaluation_time` - Defines from which time range is used to evaluate the output files. Can e.g. be usefull to ignore warm up.
# - `n_trials` - Number of optimization iterations to perform.
# - `sampler` - The optuna sampler that is use for the study.
# - `direction` - Indicates that the optimization should "minimize" or "maximize" the error metrics. Can be a list if multiple objectives are used.
# - `inner_metric` -  Applied to each simulation-observation pair independently. Can be a list if multiple objectives are used.
# - `outer_metric` - Combines results from multiple simulation-observation pairs into a single objective value. Can be a list if multiple objectives are used.

# %%
study_name = "example_points"
simfile = ROOT_DIR / "mike_autocal/tests/data/simulation_data_sns/simulation/sns_base.m21fm"
evaluation_time = slice(50, None)
n_trials = 11
sampler = optuna.samplers.GPSampler(seed=0)
direction = ["minimize"]
inner_metric = [RMSEInnerMetric()]
outer_metric = [AMEANOuterMetric()]
use_gpu=False

# %% [markdown]
# ##### Create measurement functions
#
# Measurement functions define the parameters that will be calibrated in the MIKE model. Meaningful ranges can be defined it wished.

# %%
measurement_functions = [
    ManningFile(
        filename= ROOT_DIR / "mike_autocal/tests/data/simulation_data_sns/simulation/conditions/ManningM.dfsu",
        item_name="manning",
        low=0.001,
        high=81.101,
        step=0.01,
    )]

# %% [markdown]
# ##### Create a Mapping of Simulation and Observation Data (Simulation-Observation Pairs)
#
# In order for the autocal system to recognize the observation data as measurement points, we need to specify `pair_type="point"` in the `SimObsPair`. This indicates that the data corresponds to a point observation.
#
# Additionally, to properly interpret the `dfs0` files associated with point-type observations, we need to specify the `item` number of the respective measurement in the file.

# %%
base_sim_path = ROOT_DIR / "mike_autocal/tests/data/simulation_data_sns/simulation/sns_base.m21fm - Result Files"
base_obs_path = ROOT_DIR / "mike_autocal/tests/data/simulation_data_sns/observations"

simobs = [
    SimObsPair(
        name="F3platform",
        pair_type="point",
        sim=SimulationData(
            file_path = base_sim_path / "waterlevels.dfs0",
            item=7,  
        ),
        obs=ObservationData(
            file_path = base_obs_path / "F3platform_wl.dfs0",
            item=0,  
        ),
    ),
    SimObsPair(
        name="Helgoland",
        pair_type="point",
        sim=SimulationData(
            file_path = base_sim_path / "waterlevels.dfs0",
            item=5,  
        ),
        obs=ObservationData(
            file_path = base_obs_path / "Helgoland_wl.dfs0",
            item=0,  
        ),
    ),
    SimObsPair("J61",
        pair_type="point",
        sim=SimulationData(
            file_path = base_sim_path / "waterlevels.dfs0",
            item=6,  
        ),
        obs=ObservationData(
            file_path = base_obs_path / "J61_wl.dfs0",
            item=0,  
        ),
    ),
    SimObsPair(
        name="K141",
        pair_type="point",
        sim=SimulationData(
            file_path = base_sim_path / "waterlevels.dfs0",
            item=3,  
        ),
        obs=ObservationData(
            file_path = base_obs_path / "K141_wl.dfs0",
            item=0,  
        ),
    ),
    SimObsPair(
        name="Westkapelle",
        pair_type="point",
        sim=SimulationData(
            file_path = base_sim_path / "waterlevels.dfs0",
            item=1,  
        ),
        obs=ObservationData(
            file_path = base_obs_path / "Westkapelle_wl.dfs0",
            item=0,  
        ),
    ),
    SimObsPair(
        name="ZeebruggeWielingendok_wl",
        pair_type="point",
        sim=SimulationData(
            file_path = base_sim_path / "waterlevels.dfs0",
            item=0,  
        ),
        obs=ObservationData(
            file_path = base_obs_path / "ZeebruggeWielingendok_wl.dfs0",
            item=0,  
        ),
    ),
    SimObsPair(
        name="L91",
        pair_type="point",
        sim=SimulationData(
            file_path = base_sim_path / "waterlevels.dfs0",
            item=2,  
        ),
        obs=ObservationData(
            file_path = base_obs_path / "L91_wl.dfs0",
            item=0,  
        ),
    ),]

# %% [markdown]
# ##### Create Launcher

# %%
rte = RunTimeEvaluation(
    simobs=simobs,
    inner_metric=inner_metric,
    outer_metric=outer_metric,
    frequency=50,
    logdir=Path(f"logs/simulation_{datetime.now().strftime('%Y%m%d_%H%M%S')}"),
)

launcher = Launcher(
    simfile=simfile,
    use_gpu=use_gpu,
    runtimeevaluation=rte,
)

# %% [markdown]
# ##### Create autocal object

# %%
calibration = AutoCal(
    study_name=study_name,
    launcher=launcher,
    simobs=simobs,
    inner_metric=inner_metric,  
    outer_metric=outer_metric,
    n_trials=n_trials,
    direction=direction,
    sampler=sampler, 
    measurement_functions=measurement_functions,
    evaluation_time=evaluation_time,
    verbose=False,
    load_if_exists=False,
)
calibration.run()
# Out:
# [I 2025-04-21 14:50:11,430] A new study created in Journal with name: example_points
# INFO:autocal:------------------------------------ Trial: 0 ------------------------------------
# WARNING:launcher:Runtime evaluation is not supported for CPU execution on multiple cores. Proceeding without runtime evaluation.
# Processing: 100%|██████████| 500/500 [00:44<00:00, 11.35step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.309701  451
# Helgoland                 1.264383  451
# J61                       1.125848  451
# K141                      0.278207  451
# Westkapelle               0.455529  451
# ZeebruggeWielingendok_wl  0.482989  451
# L91                       0.276634  451
# [I 2025-04-21 14:50:57,498] Trial 0 finished with value: 0.599041654325062 and parameters: {'Manning_0': 44.510999999999996, 'Manning_1': 58.001, 'Manning_2': 48.891, 'Manning_3': 44.190999999999995, 'Manning_4': 34.361, 'Manning_5': 52.381, 'Manning_6': 35.491}. Best is trial 0 with value: 0.599041654325062.
# INFO:autocal:------------------------------------ Trial: 1 ------------------------------------
# Processing: 100%|██████████| 500/500 [00:44<00:00, 11.24step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.309006  451
# Helgoland                 1.316695  451
# J61                       1.125848  451
# K141                      0.270181  451
# Westkapelle               0.432363  451
# ZeebruggeWielingendok_wl  0.457363  451
# L91                       0.262733  451
# [I 2025-04-21 14:51:43,908] Trial 1 finished with value: 0.5963128306769114 and parameters: {'Manning_0': 72.331, 'Manning_1': 78.161, 'Manning_2': 31.101000000000003, 'Manning_3': 64.21100000000001, 'Manning_4': 42.891, 'Manning_5': 46.071, 'Manning_6': 75.07100000000001}. Best is trial 1 with value: 0.5963128306769114.
# INFO:autocal:------------------------------------ Trial: 2 ------------------------------------
# Processing: 100%|██████████| 500/500 [00:52<00:00,  9.59step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.315551  451
# Helgoland                 1.186813  451
# J61                       1.019597  451
# K141                      0.326319  451
# Westkapelle               0.959323  451
# ZeebruggeWielingendok_wl  0.956762  451
# L91                       0.322717  451
# [I 2025-04-21 14:52:38,015] Trial 2 finished with value: 0.7267260251751422 and parameters: {'Manning_0': 5.761, 'Manning_1': 7.061000000000001, 'Manning_2': 1.631, 'Manning_3': 67.531, 'Manning_4': 63.111, 'Manning_5': 70.561, 'Manning_6': 79.37100000000001}. Best is trial 1 with value: 0.5963128306769114.
# INFO:autocal:------------------------------------ Trial: 3 ------------------------------------
# Processing: 100%|██████████| 500/500 [00:44<00:00, 11.15step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.325789  451
# Helgoland                 1.153994  451
# J61                       0.952948  451
# K141                      0.358299  451
# Westkapelle               0.861468  451
# ZeebruggeWielingendok_wl  0.922266  451
# L91                       0.408657  451
# [I 2025-04-21 14:53:24,850] Trial 3 finished with value: 0.7119172593826893 and parameters: {'Manning_0': 64.811, 'Manning_1': 37.431, 'Manning_2': 63.301, 'Manning_3': 9.591, 'Manning_4': 51.900999999999996, 'Manning_5': 11.621, 'Manning_6': 76.62100000000001}. Best is trial 1 with value: 0.5963128306769114.
# INFO:autocal:------------------------------------ Trial: 4 ------------------------------------
# Processing: 100%|██████████| 500/500 [00:46<00:00, 10.87step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.272752  451
# Helgoland                 1.034246  451
# J61                       1.034180  451
# K141                      0.390047  451
# Westkapelle               0.754525  451
# ZeebruggeWielingendok_wl  0.881944  451
# L91                       0.352840  451
# [I 2025-04-21 14:54:12,882] Trial 4 finished with value: 0.6743620566835836 and parameters: {'Manning_0': 42.321, 'Manning_1': 33.631, 'Manning_2': 21.451, 'Manning_3': 62.791, 'Manning_4': 36.991, 'Manning_5': 46.101, 'Manning_6': 1.521}. Best is trial 1 with value: 0.5963128306769114.
# INFO:autocal:------------------------------------ Trial: 5 ------------------------------------
# Processing: 100%|██████████| 500/500 [00:45<00:00, 11.08step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.312680  451
# Helgoland                 1.307730  451
# J61                       1.122041  451
# K141                      0.284134  451
# Westkapelle               0.397939  451
# ZeebruggeWielingendok_wl  0.461455  451
# L91                       0.256404  451
# [I 2025-04-21 14:54:59,997] Trial 5 finished with value: 0.5917689563470127 and parameters: {'Manning_0': 50.091, 'Manning_1': 49.641, 'Manning_2': 50.031, 'Manning_3': 76.54100000000001, 'Manning_4': 55.301, 'Manning_5': 29.151000000000003, 'Manning_6': 35.440999999999995}. Best is trial 5 with value: 0.5917689563470127.
# INFO:autocal:------------------------------------ Trial: 6 ------------------------------------
# Processing: 100%|██████████| 500/500 [00:43<00:00, 11.38step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.321648  451
# Helgoland                 1.086122  451
# J61                       0.845275  451
# K141                      0.319565  451
# Westkapelle               1.120184  451
# ZeebruggeWielingendok_wl  1.159268  451
# L91                       0.384668  451
# [I 2025-04-21 14:55:45,958] Trial 6 finished with value: 0.7481042001594311 and parameters: {'Manning_0': 56.580999999999996, 'Manning_1': 4.881, 'Manning_2': 54.080999999999996, 'Manning_3': 54.391, 'Manning_4': 17.061, 'Manning_5': 10.451, 'Manning_6': 25.581000000000003}. Best is trial 5 with value: 0.5917689563470127.
# INFO:autocal:------------------------------------ Trial: 7 ------------------------------------
# Processing: 100%|██████████| 500/500 [00:43<00:00, 11.41step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.316822  451
# Helgoland                 1.038086  451
# J61                       0.769209  451
# K141                      0.351273  451
# Westkapelle               0.986971  451
# ZeebruggeWielingendok_wl  1.084110  451
# L91                       0.399539  451
# [I 2025-04-21 14:56:31,809] Trial 7 finished with value: 0.7065729036229411 and parameters: {'Manning_0': 29.501, 'Manning_1': 46.241, 'Manning_2': 35.571, 'Manning_3': 80.161, 'Manning_4': 8.270999999999999, 'Manning_5': 16.941000000000003, 'Manning_6': 13.081}. Best is trial 5 with value: 0.5917689563470127.
# INFO:autocal:------------------------------------ Trial: 8 ------------------------------------
# Processing: 100%|██████████| 500/500 [00:49<00:00, 10.07step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.325252  451
# Helgoland                 1.062545  451
# J61                       0.833849  451
# K141                      0.386979  451
# Westkapelle               0.949781  451
# ZeebruggeWielingendok_wl  1.032677  451
# L91                       0.453013  451
# [I 2025-04-21 14:57:23,471] Trial 8 finished with value: 0.7205850481193783 and parameters: {'Manning_0': 52.971, 'Manning_1': 20.541, 'Manning_2': 37.821, 'Manning_3': 19.821, 'Manning_4': 12.891, 'Manning_5': 8.951, 'Manning_6': 53.231}. Best is trial 5 with value: 0.5917689563470127.
# INFO:autocal:------------------------------------ Trial: 9 ------------------------------------
# Processing: 100%|██████████| 500/500 [00:47<00:00, 10.55step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.303034  451
# Helgoland                 0.968185  451
# J61                       0.735372  451
# K141                      0.387274  451
# Westkapelle               1.101855  451
# ZeebruggeWielingendok_wl  1.196359  451
# L91                       0.477914  451
# [I 2025-04-21 14:58:12,920] Trial 9 finished with value: 0.7385706034784335 and parameters: {'Manning_0': 11.201, 'Manning_1': 15.940999999999999, 'Manning_2': 29.901000000000003, 'Manning_3': 66.59100000000001, 'Manning_4': 7.871, 'Manning_5': 67.96100000000001, 'Manning_6': 7.791}. Best is trial 5 with value: 0.5917689563470127.
# INFO:autocal:------------------------------------ Trial: 10 ------------------------------------
# Processing: 100%|██████████| 500/500 [00:43<00:00, 11.48step/s]
# INFO:autocal:InnerEvaluation(metric=RMSE):
#                             values    n
# name
# F3platform                0.298995  451
# Helgoland                 1.328145  451
# J61                       1.201639  451
# K141                      0.314122  451
# Westkapelle               0.338281  451
# ZeebruggeWielingendok_wl  0.370939  451
# L91                       0.306478  451
# [I 2025-04-21 14:59:01,864] Trial 10 finished with value: 0.5940855401333399 and parameters: {'Manning_0': 52.04099999999998, 'Manning_1': 67.841, 'Manning_2': 53.84099999999999, 'Manning_3': 68.19099999999999, 'Manning_4': 56.30099999999999, 'Manning_5': 54.34099999999999, 'Manning_6': 31.240999999999996}. Best is trial 5 with value: 0.5917689563470127.

# %% [markdown]
# ##### For testing
# Trial 10 should have an objective value of `0.5940855401333399 `
